# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('apto_results_final.csv')

# %%
df[df['others'] == '0']['others'].count()
# Out:
# 573

# %%
df.price.max()
# Out:
# 530000

# %%
df = df[df['price'] <= 20000]

# %%
df.price.hist()
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#               area     bedrooms    bathrooms      garages         price  \
# count  2112.000000  2112.000000  2112.000000  2112.000000   2112.000000
# mean     83.475852     2.244318     1.799242     1.396307   2340.597538
# std      57.883828     0.895256     1.172655     0.990550   2089.327004
# min      10.000000     1.000000     0.000000     0.000000    450.000000
# 25%      50.000000     2.000000     1.000000     1.000000   1177.500000
# 50%      65.000000     2.000000     1.000000     1.000000   1700.000000
# 75%      90.250000     3.000000     2.000000     2.000000   2800.000000
# max     652.000000     5.000000     8.000000    25.000000  20000.000000
#
#               condo
# count   2112.000000
# mean     550.690341
# std     1884.474954
# min        0.000000
# 25%      300.000000
# 50%      400.000000
# 75%      600.000000
# max    74765.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))
plt.scatter(df['area'],df['price'], alpha = 0.2, color = 'k')

# %%
sns.pairplot(df, kind = 'reg')

# %%
df = df[df['condo'] <= 10000]

# %%
df = df[df['price'] <= 20000]

# %%
sns.pairplot(df, kind = 'reg')

# %%
df.corr()
# Out:
#                area  bedrooms  bathrooms   garages     price     condo
# area       1.000000  0.713868   0.717463  0.613677  0.789371  0.751001
# bedrooms   0.713868  1.000000   0.654270  0.498708  0.577239  0.576662
# bathrooms  0.717463  0.654270   1.000000  0.551122  0.690112  0.629106
# garages    0.613677  0.498708   0.551122  1.000000  0.639632  0.507297
# price      0.789371  0.577239   0.690112  0.639632  1.000000  0.651290
# condo      0.751001  0.576662   0.629106  0.507297  0.651290  1.000000

# %%
df.boxplot('price')
# Out:
# <AxesSubplot:>

# %%
df2 = df[df['price'] <= 5000]

# %%
df2.boxplot('price')
# Out:
# <AxesSubplot:>
