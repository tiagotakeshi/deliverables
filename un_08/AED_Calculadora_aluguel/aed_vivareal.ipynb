# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('apto_results_final.csv')

# %%
sns.distplot(df['price'])
# Out:
# C:\Users\Takeshi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
df.describe()
# Out:
#               area     bedrooms    bathrooms      garages          price  \
# count  2122.000000  2122.000000  2122.000000  2122.000000    2122.000000
# mean     84.394910     2.249764     1.813855     1.407163    2975.938737
# std      60.013526     0.897801     1.197095     1.010135   15665.184585
# min      10.000000     1.000000     0.000000     0.000000     450.000000
# 25%      50.000000     2.000000     1.000000     1.000000    1190.000000
# 50%      65.000000     2.000000     1.000000     1.000000    1700.000000
# 75%      91.000000     3.000000     2.000000     2.000000    2800.000000
# max     652.000000     5.000000     8.000000    25.000000  530000.000000
#
#               condo
# count   2122.000000
# mean     554.993402
# std     1881.795756
# min        0.000000
# 25%      300.000000
# 50%      400.000000
# 75%      600.000000
# max    74765.000000

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['area'],df['price'], color = 'r', alpha=0.5)
plt.ylim([0,600000])
plt.xlabel('Área',fontsize=12)
plt.ylabel('Preço do Aluguel',fontsize=12)
# Out:
# Text(0, 0.5, 'Preço do Aluguel')

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['area'],df['condo'], color = 'k', alpha=0.2)
plt.ylim([0,80000])
plt.xlabel('Área',fontsize=12)
plt.ylabel('Preço do Condomínio',fontsize=12)
# Out:
# Text(0, 0.5, 'Preço do Condomínio')

# %%
df.boxplot('price')
# Out:
# <AxesSubplot:>

# %%
df.boxplot('condo')
# Out:
# <AxesSubplot:>

# %%
df2 = df[df['price'] > 200000]

# %%
df2 = df2.append(df[df['condo'] > 20000])

# %%
df.drop(labels = df2.index,inplace=True)

# %%
df.shape
# Out:
# (2116, 11)

# %%
print(df['price'].max())
print(df['condo'].max())
# Out:
# 25000
# 3190.0

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['area'],df['price'], color = 'r', alpha=0.5)
plt.ylim([0,30000])
plt.xlabel('Área',fontsize=12)
plt.ylabel('Preço do Aluguel',fontsize=12)
# Out:
# Text(0, 0.5, 'Preço do Aluguel')

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['area'],df['condo'], color = 'k', alpha=0.2)
plt.ylim([0,5000])
plt.xlabel('Área',fontsize=12)
plt.ylabel('Preço do Condomínio',fontsize=12)
# Out:
# Text(0, 0.5, 'Preço do Condomínio')

# %%
df.boxplot('price')
# Out:
# <AxesSubplot:>

# %%
df.boxplot('condo')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df, kind='reg')

# %%
# a área tem a maior correlação com os preços, porém as demais características estão mais relacionadas ao tamanho do imóvel doque ao preço
df.corr()
# Out:
#                area  bedrooms  bathrooms   garages     price     condo
# area       1.000000  0.707899   0.724010  0.632521  0.792142  0.764374
# bedrooms   0.707899  1.000000   0.656737  0.501977  0.543714  0.578205
# bathrooms  0.724010  0.656737   1.000000  0.558893  0.679658  0.636890
# garages    0.632521  0.501977   0.558893  1.000000  0.637829  0.529756
# price      0.792142  0.543714   0.679658  0.637829  1.000000  0.656153
# condo      0.764374  0.578205   0.636890  0.529756  0.656153  1.000000

# %%
df.describe()
# Out:
#               area     bedrooms    bathrooms      garages         price  \
# count  2116.000000  2116.000000  2116.000000  2116.000000   2116.000000
# mean     84.404537     2.249055     1.812854     1.406900   2410.300567
# std      60.060174     0.897527     1.197296     1.011204   2409.026038
# min      10.000000     1.000000     0.000000     0.000000    450.000000
# 25%      50.000000     2.000000     1.000000     1.000000   1188.750000
# 50%      65.000000     2.000000     1.000000     1.000000   1700.000000
# 75%      91.000000     3.000000     2.000000     2.000000   2800.000000
# max     652.000000     5.000000     8.000000    25.000000  25000.000000
#
#              condo
# count  2116.000000
# mean    492.988658
# std     374.200045
# min       0.000000
# 25%     300.000000
# 50%     400.000000
# 75%     600.000000
# max    3190.000000

# %%
sns.lmplot(x='area', y='price', data=df)

# %%
sns.lmplot(x='bedrooms', y='area', data=df)

# %%
sns.lmplot(x='bathrooms', y='area', data=df)

# %%
sns.lmplot(x='garages', y='area', data=df)

# %%
sns.lmplot(x='condo', y='area', data=df)

# %%
sns.lmplot(x='price', y='area', data=df)

# %%
sns.distplot(df.price)
# Out:
# C:\Users\Takeshi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
df2 = np.log(df['price'])

# %%
sns.distplot(df2)
# Out:
# C:\Users\Takeshi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
df['condo'].hist()
# Out:
# <AxesSubplot:>

# %%
df3 = df[df['condo']!=0]

# %%
df4 = np.log(df3['condo'])

# %%
sns.distplot(df4)
# Out:
# C:\Users\Takeshi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='condo', ylabel='Density'>
